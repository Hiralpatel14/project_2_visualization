# %%
# Import libs
import requests
import pprint
import numpy as np
import pandas as pd
import json
from sqlalchemy import create_engine
from geojson import Feature, FeatureCollection, Point
import matplotlib.pyplot as plt

# %%
# API base URL
url = "http://api.worldbank.org/v2/"
# csv file path
country_gdp_file = "../Resources/country_gdp.csv"
country_pop_file = "../Resources/country_pop.csv"

format = "json"
page = 350

# http://api.worldbank.org/v2/country/all/?per_page=350&format=json

# Get country information in JSON format
data = requests.get(f"{url}country/all/?per_page={page}&format={format}").json()
pprint.pprint(data[1])
# Out:
# [{'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': 'Oranjestad',
#   'id': 'ABW',
#   'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#   'iso2Code': 'AW',
#   'latitude': '12.5167',
#   'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#   'longitude': '-70.0167',
#   'name': 'Aruba',
#   'region': {'id': 'LCN',
#              'iso2code': 'ZJ',
#              'value': 'Latin America & Caribbean '}},
#  {'adminregion': {'id': 'SAS', 'iso2code': '8S', 'value': 'South Asia'},
#   'capitalCity': 'Kabul',
#   'id': 'AFG',
#   'incomeLevel': {'id': 'LIC', 'iso2code': 'XM', 'value': 'Low income'},
#   'iso2Code': 'AF',
#   'latitude': '34.5228',
#   'lendingType': {'id': 'IDX', 'iso2code': 'XI', 'value': 'IDA'},
#   'longitude': '69.1761',
#   'name': 'Afghanistan',
#   'region': {'id': 'SAS', 'iso2code': '8S', 'value': 'South Asia'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'AFR',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': 'A9',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'Africa',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': 'SSA',
#                   'iso2code': 'ZF',
#                   'value': 'Sub-Saharan Africa (excluding high income)'},
#   'capitalCity': 'Luanda',
#   'id': 'AGO',
#   'incomeLevel': {'id': 'LMC',
#                   'iso2code': 'XN',
#                   'value': 'Lower middle income'},
#   'iso2Code': 'AO',
#   'latitude': '-8.81155',
#   'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#   'longitude': '13.242',
#   'name': 'Angola',
#   'region': {'id': 'SSF', 'iso2code': 'ZG', 'value': 'Sub-Saharan Africa '}},
#  {'adminregion': {'id': 'ECA',
#                   'iso2code': '7E',
#                   'value': 'Europe & Central Asia (excluding high income)'},
#   'capitalCity': 'Tirane',
#   'id': 'ALB',
#   'incomeLevel': {'id': 'UMC',
#                   'iso2code': 'XT',
#                   'value': 'Upper middle income'},
#   'iso2Code': 'AL',
#   'latitude': '41.3317',
#   'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#   'longitude': '19.8172',
#   'name': 'Albania',
#   'region': {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Europe & Central Asia'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': 'Andorra la Vella',
#   'id': 'AND',
#   'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#   'iso2Code': 'AD',
#   'latitude': '42.5075',
#   'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#   'longitude': '1.5218',
#   'name': 'Andorra',
#   'region': {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Europe & Central Asia'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'ANR',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': 'L5',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'Andean Region',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'ARB',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': '1A',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'Arab World',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': 'Abu Dhabi',
#   'id': 'ARE',
#   'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#   'iso2Code': 'AE',
#   'latitude': '24.4764',
#   'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#   'longitude': '54.3705',
#   'name': 'United Arab Emirates',
#   'region': {'id': 'MEA',
#              'iso2code': 'ZQ',
#              'value': 'Middle East & North Africa'}},
#  {'adminregion': {'id': 'LAC',
#                   'iso2code': 'XJ',
#                   'value': 'Latin America & Caribbean (excluding high income)'},
#   'capitalCity': 'Buenos Aires',
#   'id': 'ARG',
#   'incomeLevel': {'id': 'UMC',
#                   'iso2code': 'XT',
#                   'value': 'Upper middle income'},
#   'iso2Code': 'AR',
#   'latitude': '-34.6118',
#   'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#   'longitude': '-58.4173',
#   'name': 'Argentina',
#   'region': {'id': 'LCN',
#              'iso2code': 'ZJ',
#              'value': 'Latin America & Caribbean '}},
#  {'adminregion': {'id': 'ECA',
#                   'iso2code': '7E',
#                   'value': 'Europe & Central Asia (excluding high income)'},
#   'capitalCity': 'Yerevan',
#   'id': 'ARM',
#   'incomeLevel': {'id': 'UMC',
#                   'iso2code': 'XT',
#                   'value': 'Upper middle income'},
#   'iso2Code': 'AM',
#   'latitude': '40.1596',
#   'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#   'longitude': '44.509',
#   'name': 'Armenia',
#   'region': {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Europe & Central Asia'}},
#  {'adminregion': {'id': 'EAP',
#                   'iso2code': '4E',
#                   'value': 'East Asia & Pacific (excluding high income)'},
#   'capitalCity': 'Pago Pago',
#   'id': 'ASM',
#   'incomeLevel': {'id': 'UMC',
#                   'iso2code': 'XT',
#                   'value': 'Upper middle income'},
#   'iso2Code': 'AS',
#   'latitude': '-14.2846',
#   'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#   'longitude': '-170.691',
#   'name': 'American Samoa',
#   'region': {'id': 'EAS', 'iso2code': 'Z4', 'value': 'East Asia & Pacific'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': "Saint John's",
#   'id': 'ATG',
#   'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#   'iso2Code': 'AG',
#   'latitude': '17.1175',
#   'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#   'longitude': '-61.8456',
#   'name': 'Antigua and Barbuda',
#   'region': {'id': 'LCN',
#              'iso2code': 'ZJ',
#              'value': 'Latin America & Caribbean '}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': 'Canberra',
#   'id': 'AUS',
#   'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#   'iso2Code': 'AU',
#   'latitude': '-35.282',
#   'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#   'longitude': '149.129',
#   'name': 'Australia',
#   'region': {'id': 'EAS', 'iso2code': 'Z4', 'value': 'East Asia & Pacific'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': 'Vienna',
#   'id': 'AUT',
#   'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#   'iso2Code': 'AT',
#   'latitude': '48.2201',
#   'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#   'longitude': '16.3798',
#   'name': 'Austria',
#   'region': {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Europe & Central Asia'}},
#  {'adminregion': {'id': 'ECA',
#                   'iso2code': '7E',
#                   'value': 'Europe & Central Asia (excluding high income)'},
#   'capitalCity': 'Baku',
#   'id': 'AZE',
#   'incomeLevel': {'id': 'UMC',
#                   'iso2code': 'XT',
#                   'value': 'Upper middle income'},
#   'iso2Code': 'AZ',
#   'latitude': '40.3834',
#   'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#   'longitude': '49.8932',
#   'name': 'Azerbaijan',
#   'region': {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Europe & Central Asia'}},
#  {'adminregion': {'id': 'SSA',
#                   'iso2code': 'ZF',
#                   'value': 'Sub-Saharan Africa (excluding high income)'},
#   'capitalCity': 'Bujumbura',
#   'id': 'BDI',
#   'incomeLevel': {'id': 'LIC', 'iso2code': 'XM', 'value': 'Low income'},
#   'iso2Code': 'BI',
#   'latitude': '-3.3784',
#   'lendingType': {'id': 'IDX', 'iso2code': 'XI', 'value': 'IDA'},
#   'longitude': '29.3639',
#   'name': 'Burundi',
#   'region': {'id': 'SSF', 'iso2code': 'ZG', 'value': 'Sub-Saharan Africa '}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'BEA',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': 'B4',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'East Asia & Pacific (IBRD-only countries)',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'BEC',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': 'B7',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'Europe & Central Asia (IBRD-only countries)',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': 'Brussels',
#   'id': 'BEL',
#   'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#   'iso2Code': 'BE',
#   'latitude': '50.8371',
#   'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#   'longitude': '4.36761',
#   'name': 'Belgium',
#   'region': {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Europe & Central Asia'}},
#  {'adminregion': {'id': 'SSA',
#                   'iso2code': 'ZF',
#                   'value': 'Sub-Saharan Africa (excluding high income)'},
#   'capitalCity': 'Porto-Novo',
#   'id': 'BEN',
#   'incomeLevel': {'id': 'LIC', 'iso2code': 'XM', 'value': 'Low income'},
#   'iso2Code': 'BJ',
#   'latitude': '6.4779',
#   'lendingType': {'id': 'IDX', 'iso2code': 'XI', 'value': 'IDA'},
#   'longitude': '2.6323',
#   'name': 'Benin',
#   'region': {'id': 'SSF', 'iso2code': 'ZG', 'value': 'Sub-Saharan Africa '}},
#  {'adminregion': {'id': 'SSA',
#                   'iso2code': 'ZF',
#                   'value': 'Sub-Saharan Africa (excluding high income)'},
#   'capitalCity': 'Ouagadougou',
#   'id': 'BFA',
#   'incomeLevel': {'id': 'LIC', 'iso2code': 'XM', 'value': 'Low income'},
#   'iso2Code': 'BF',
#   'latitude': '12.3605',
#   'lendingType': {'id': 'IDX', 'iso2code': 'XI', 'value': 'IDA'},
#   'longitude': '-1.53395',
#   'name': 'Burkina Faso',
#   'region': {'id': 'SSF', 'iso2code': 'ZG', 'value': 'Sub-Saharan Africa '}},
#  {'adminregion': {'id': 'SAS', 'iso2code': '8S', 'value': 'South Asia'},
#   'capitalCity': 'Dhaka',
#   'id': 'BGD',
#   'incomeLevel': {'id': 'LMC',
#                   'iso2code': 'XN',
#                   'value': 'Lower middle income'},
#   'iso2Code': 'BD',
#   'latitude': '23.7055',
#   'lendingType': {'id': 'IDX', 'iso2code': 'XI', 'value': 'IDA'},
#   'longitude': '90.4113',
#   'name': 'Bangladesh',
#   'region': {'id': 'SAS', 'iso2code': '8S', 'value': 'South Asia'}},
#  {'adminregion': {'id': 'ECA',
#                   'iso2code': '7E',
#                   'value': 'Europe & Central Asia (excluding high income)'},
#   'capitalCity': 'Sofia',
#   'id': 'BGR',
#   'incomeLevel': {'id': 'UMC',
#                   'iso2code': 'XT',
#                   'value': 'Upper middle income'},
#   'iso2Code': 'BG',
#   'latitude': '42.7105',
#   'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#   'longitude': '23.3238',
#   'name': 'Bulgaria',
#   'region': {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Europe & Central Asia'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'BHI',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': 'B1',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'IBRD countries classified as high income',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': 'Manama',
#   'id': 'BHR',
#   'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#   'iso2Code': 'BH',
#   'latitude': '26.1921',
#   'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#   'longitude': '50.5354',
#   'name': 'Bahrain',
#   'region': {'id': 'MEA',
#              'iso2code': 'ZQ',
#              'value': 'Middle East & North Africa'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': 'Nassau',
#   'id': 'BHS',
#   'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#   'iso2Code': 'BS',
#   'latitude': '25.0661',
#   'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#   'longitude': '-77.339',
#   'name': 'Bahamas, The',
#   'region': {'id': 'LCN',
#              'iso2code': 'ZJ',
#              'value': 'Latin America & Caribbean '}},
#  {'adminregion': {'id': 'ECA',
#                   'iso2code': '7E',
#                   'value': 'Europe & Central Asia (excluding high income)'},
#   'capitalCity': 'Sarajevo',
#   'id': 'BIH',
#   'incomeLevel': {'id': 'UMC',
#                   'iso2code': 'XT',
#                   'value': 'Upper middle income'},
#   'iso2Code': 'BA',
#   'latitude': '43.8607',
#   'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#   'longitude': '18.4214',
#   'name': 'Bosnia and Herzegovina',
#   'region': {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Europe & Central Asia'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'BLA',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': 'B2',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'Latin America & the Caribbean (IBRD-only countries)',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': 'ECA',
#                   'iso2code': '7E',
#                   'value': 'Europe & Central Asia (excluding high income)'},
#   'capitalCity': 'Minsk',
#   'id': 'BLR',
#   'incomeLevel': {'id': 'UMC',
#                   'iso2code': 'XT',
#                   'value': 'Upper middle income'},
#   'iso2Code': 'BY',
#   'latitude': '53.9678',
#   'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#   'longitude': '27.5766',
#   'name': 'Belarus',
#   'region': {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Europe & Central Asia'}},
#  {'adminregion': {'id': 'LAC',
#                   'iso2code': 'XJ',
#                   'value': 'Latin America & Caribbean (excluding high income)'},
#   'capitalCity': 'Belmopan',
#   'id': 'BLZ',
#   'incomeLevel': {'id': 'UMC',
#                   'iso2code': 'XT',
#                   'value': 'Upper middle income'},
#   'iso2Code': 'BZ',
#   'latitude': '17.2534',
#   'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#   'longitude': '-88.7713',
#   'name': 'Belize',
#   'region': {'id': 'LCN',
#              'iso2code': 'ZJ',
#              'value': 'Latin America & Caribbean '}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'BMN',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': 'B3',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'Middle East & North Africa (IBRD-only countries)',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': 'Hamilton',
#   'id': 'BMU',
#   'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#   'iso2Code': 'BM',
#   'latitude': '32.3293',
#   'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#   'longitude': '-64.706',
#   'name': 'Bermuda',
#   'region': {'id': 'NAC', 'iso2code': 'XU', 'value': 'North America'}},
#  {'adminregion': {'id': 'LAC',
#                   'iso2code': 'XJ',
#                   'value': 'Latin America & Caribbean (excluding high income)'},
#   'capitalCity': 'La Paz',
#   'id': 'BOL',
#   'incomeLevel': {'id': 'LMC',
#                   'iso2code': 'XN',
#                   'value': 'Lower middle income'},
#   'iso2Code': 'BO',
#   'latitude': '-13.9908',
#   'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#   'longitude': '-66.1936',
#   'name': 'Bolivia',
#   'region': {'id': 'LCN',
#              'iso2code': 'ZJ',
#              'value': 'Latin America & Caribbean '}},
#  {'adminregion': {'id': 'LAC',
#                   'iso2code': 'XJ',
#                   'value': 'Latin America & Caribbean (excluding high income)'},
#   'capitalCity': 'Brasilia',
#   'id': 'BRA',
#   'incomeLevel': {'id': 'UMC',
#                   'iso2code': 'XT',
#                   'value': 'Upper middle income'},
#   'iso2Code': 'BR',
#   'latitude': '-15.7801',
#   'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#   'longitude': '-47.9292',
#   'name': 'Brazil',
#   'region': {'id': 'LCN',
#              'iso2code': 'ZJ',
#              'value': 'Latin America & Caribbean '}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': 'Bridgetown',
#   'id': 'BRB',
#   'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#   'iso2Code': 'BB',
#   'latitude': '13.0935',
#   'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#   'longitude': '-59.6105',
#   'name': 'Barbados',
#   'region': {'id': 'LCN',
#              'iso2code': 'ZJ',
#              'value': 'Latin America & Caribbean '}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': 'Bandar Seri Begawan',
#   'id': 'BRN',
#   'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#   'iso2Code': 'BN',
#   'latitude': '4.94199',
#   'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#   'longitude': '114.946',
#   'name': 'Brunei Darussalam',
#   'region': {'id': 'EAS', 'iso2code': 'Z4', 'value': 'East Asia & Pacific'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'BSS',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': 'B6',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'Sub-Saharan Africa (IBRD-only countries)',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': 'SAS', 'iso2code': '8S', 'value': 'South Asia'},
#   'capitalCity': 'Thimphu',
#   'id': 'BTN',
#   'incomeLevel': {'id': 'LMC',
#                   'iso2code': 'XN',
#                   'value': 'Lower middle income'},
#   'iso2Code': 'BT',
#   'latitude': '27.5768',
#   'lendingType': {'id': 'IDX', 'iso2code': 'XI', 'value': 'IDA'},
#   'longitude': '89.6177',
#   'name': 'Bhutan',
#   'region': {'id': 'SAS', 'iso2code': '8S', 'value': 'South Asia'}},
#  {'adminregion': {'id': 'SSA',
#                   'iso2code': 'ZF',
#                   'value': 'Sub-Saharan Africa (excluding high income)'},
#   'capitalCity': 'Gaborone',
#   'id': 'BWA',
#   'incomeLevel': {'id': 'UMC',
#                   'iso2code': 'XT',
#                   'value': 'Upper middle income'},
#   'iso2Code': 'BW',
#   'latitude': '-24.6544',
#   'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#   'longitude': '25.9201',
#   'name': 'Botswana',
#   'region': {'id': 'SSF', 'iso2code': 'ZG', 'value': 'Sub-Saharan Africa '}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'CAA',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': 'C9',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'Sub-Saharan Africa (IFC classification)',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': 'SSA',
#                   'iso2code': 'ZF',
#                   'value': 'Sub-Saharan Africa (excluding high income)'},
#   'capitalCity': 'Bangui',
#   'id': 'CAF',
#   'incomeLevel': {'id': 'LIC', 'iso2code': 'XM', 'value': 'Low income'},
#   'iso2Code': 'CF',
#   'latitude': '5.63056',
#   'lendingType': {'id': 'IDX', 'iso2code': 'XI', 'value': 'IDA'},
#   'longitude': '21.6407',
#   'name': 'Central African Republic',
#   'region': {'id': 'SSF', 'iso2code': 'ZG', 'value': 'Sub-Saharan Africa '}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': 'Ottawa',
#   'id': 'CAN',
#   'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#   'iso2Code': 'CA',
#   'latitude': '45.4215',
#   'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#   'longitude': '-75.6919',
#   'name': 'Canada',
#   'region': {'id': 'NAC', 'iso2code': 'XU', 'value': 'North America'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'CEA',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': 'C4',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'East Asia and the Pacific (IFC classification)',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'CEB',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': 'B8',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'Central Europe and the Baltics',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'CEU',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': 'C5',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'Europe and Central Asia (IFC classification)',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': 'Bern',
#   'id': 'CHE',
#   'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#   'iso2Code': 'CH',
#   'latitude': '46.948',
#   'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#   'longitude': '7.44821',
#   'name': 'Switzerland',
#   'region': {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Europe & Central Asia'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'CHI',
#   'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#   'iso2Code': 'JG',
#   'latitude': '',
#   'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#   'longitude': '',
#   'name': 'Channel Islands',
#   'region': {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Europe & Central Asia'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': 'Santiago',
#   'id': 'CHL',
#   'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#   'iso2Code': 'CL',
#   'latitude': '-33.475',
#   'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#   'longitude': '-70.6475',
#   'name': 'Chile',
#   'region': {'id': 'LCN',
#              'iso2code': 'ZJ',
#              'value': 'Latin America & Caribbean '}},
#  {'adminregion': {'id': 'EAP',
#                   'iso2code': '4E',
#                   'value': 'East Asia & Pacific (excluding high income)'},
#   'capitalCity': 'Beijing',
#   'id': 'CHN',
#   'incomeLevel': {'id': 'UMC',
#                   'iso2code': 'XT',
#                   'value': 'Upper middle income'},
#   'iso2Code': 'CN',
#   'latitude': '40.0495',
#   'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#   'longitude': '116.286',
#   'name': 'China',
#   'region': {'id': 'EAS', 'iso2code': 'Z4', 'value': 'East Asia & Pacific'}},
#  {'adminregion': {'id': 'SSA',
#                   'iso2code': 'ZF',
#                   'value': 'Sub-Saharan Africa (excluding high income)'},
#   'capitalCity': 'Yamoussoukro',
#   'id': 'CIV',
#   'incomeLevel': {'id': 'LMC',
#                   'iso2code': 'XN',
#                   'value': 'Lower middle income'},
#   'iso2Code': 'CI',
#   'latitude': '5.332',
#   'lendingType': {'id': 'IDX', 'iso2code': 'XI', 'value': 'IDA'},
#   'longitude': '-4.0305',
#   'name': "Cote d'Ivoire",
#   'region': {'id': 'SSF', 'iso2code': 'ZG', 'value': 'Sub-Saharan Africa '}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'CLA',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': 'C6',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'Latin America and the Caribbean (IFC classification)',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'CME',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': 'C7',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'Middle East and North Africa (IFC classification)',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': 'SSA',
#                   'iso2code': 'ZF',
#                   'value': 'Sub-Saharan Africa (excluding high income)'},
#   'capitalCity': 'Yaounde',
#   'id': 'CMR',
#   'incomeLevel': {'id': 'LMC',
#                   'iso2code': 'XN',
#                   'value': 'Lower middle income'},
#   'iso2Code': 'CM',
#   'latitude': '3.8721',
#   'lendingType': {'id': 'IDB', 'iso2code': 'XH', 'value': 'Blend'},
#   'longitude': '11.5174',
#   'name': 'Cameroon',
#   'region': {'id': 'SSF', 'iso2code': 'ZG', 'value': 'Sub-Saharan Africa '}},
#  {'adminregion': {'id': 'SSA',
#                   'iso2code': 'ZF',
#                   'value': 'Sub-Saharan Africa (excluding high income)'},
#   'capitalCity': 'Kinshasa',
#   'id': 'COD',
#   'incomeLevel': {'id': 'LIC', 'iso2code': 'XM', 'value': 'Low income'},
#   'iso2Code': 'CD',
#   'latitude': '-4.325',
#   'lendingType': {'id': 'IDX', 'iso2code': 'XI', 'value': 'IDA'},
#   'longitude': '15.3222',
#   'name': 'Congo, Dem. Rep.',
#   'region': {'id': 'SSF', 'iso2code': 'ZG', 'value': 'Sub-Saharan Africa '}},
#  {'adminregion': {'id': 'SSA',
#                   'iso2code': 'ZF',
#                   'value': 'Sub-Saharan Africa (excluding high income)'},
#   'capitalCity': 'Brazzaville',
#   'id': 'COG',
#   'incomeLevel': {'id': 'LMC',
#                   'iso2code': 'XN',
#                   'value': 'Lower middle income'},
#   'iso2Code': 'CG',
#   'latitude': '-4.2767',
#   'lendingType': {'id': 'IDB', 'iso2code': 'XH', 'value': 'Blend'},
#   'longitude': '15.2662',
#   'name': 'Congo, Rep.',
#   'region': {'id': 'SSF', 'iso2code': 'ZG', 'value': 'Sub-Saharan Africa '}},
#  {'adminregion': {'id': 'LAC',
#                   'iso2code': 'XJ',
#                   'value': 'Latin America & Caribbean (excluding high income)'},
#   'capitalCity': 'Bogota',
#   'id': 'COL',
#   'incomeLevel': {'id': 'UMC',
#                   'iso2code': 'XT',
#                   'value': 'Upper middle income'},
#   'iso2Code': 'CO',
#   'latitude': '4.60987',
#   'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#   'longitude': '-74.082',
#   'name': 'Colombia',
#   'region': {'id': 'LCN',
#              'iso2code': 'ZJ',
#              'value': 'Latin America & Caribbean '}},
#  {'adminregion': {'id': 'SSA',
#                   'iso2code': 'ZF',
#                   'value': 'Sub-Saharan Africa (excluding high income)'},
#   'capitalCity': 'Moroni',
#   'id': 'COM',
#   'incomeLevel': {'id': 'LMC',
#                   'iso2code': 'XN',
#                   'value': 'Lower middle income'},
#   'iso2Code': 'KM',
#   'latitude': '-11.6986',
#   'lendingType': {'id': 'IDX', 'iso2code': 'XI', 'value': 'IDA'},
#   'longitude': '43.2418',
#   'name': 'Comoros',
#   'region': {'id': 'SSF', 'iso2code': 'ZG', 'value': 'Sub-Saharan Africa '}},
#  {'adminregion': {'id': 'SSA',
#                   'iso2code': 'ZF',
#                   'value': 'Sub-Saharan Africa (excluding high income)'},
#   'capitalCity': 'Praia',
#   'id': 'CPV',
#   'incomeLevel': {'id': 'LMC',
#                   'iso2code': 'XN',
#                   'value': 'Lower middle income'},
#   'iso2Code': 'CV',
#   'latitude': '14.9218',
#   'lendingType': {'id': 'IDB', 'iso2code': 'XH', 'value': 'Blend'},
#   'longitude': '-23.5087',
#   'name': 'Cabo Verde',
#   'region': {'id': 'SSF', 'iso2code': 'ZG', 'value': 'Sub-Saharan Africa '}},
#  {'adminregion': {'id': 'LAC',
#                   'iso2code': 'XJ',
#                   'value': 'Latin America & Caribbean (excluding high income)'},
#   'capitalCity': 'San Jose',
#   'id': 'CRI',
#   'incomeLevel': {'id': 'UMC',
#                   'iso2code': 'XT',
#                   'value': 'Upper middle income'},
#   'iso2Code': 'CR',
#   'latitude': '9.63701',
#   'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#   'longitude': '-84.0089',
#   'name': 'Costa Rica',
#   'region': {'id': 'LCN',
#              'iso2code': 'ZJ',
#              'value': 'Latin America & Caribbean '}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'CSA',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': 'C8',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'South Asia (IFC classification)',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'CSS',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': 'S3',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'Caribbean small states',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': 'LAC',
#                   'iso2code': 'XJ',
#                   'value': 'Latin America & Caribbean (excluding high income)'},
#   'capitalCity': 'Havana',
#   'id': 'CUB',
#   'incomeLevel': {'id': 'UMC',
#                   'iso2code': 'XT',
#                   'value': 'Upper middle income'},
#   'iso2Code': 'CU',
#   'latitude': '23.1333',
#   'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#   'longitude': '-82.3667',
#   'name': 'Cuba',
#   'region': {'id': 'LCN',
#              'iso2code': 'ZJ',
#              'value': 'Latin America & Caribbean '}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': 'Willemstad',
#   'id': 'CUW',
#   'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#   'iso2Code': 'CW',
#   'latitude': '',
#   'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#   'longitude': '',
#   'name': 'Curacao',
#   'region': {'id': 'LCN',
#              'iso2code': 'ZJ',
#              'value': 'Latin America & Caribbean '}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': 'George Town',
#   'id': 'CYM',
#   'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#   'iso2Code': 'KY',
#   'latitude': '19.3022',
#   'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#   'longitude': '-81.3857',
#   'name': 'Cayman Islands',
#   'region': {'id': 'LCN',
#              'iso2code': 'ZJ',
#              'value': 'Latin America & Caribbean '}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': 'Nicosia',
#   'id': 'CYP',
#   'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#   'iso2Code': 'CY',
#   'latitude': '35.1676',
#   'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#   'longitude': '33.3736',
#   'name': 'Cyprus',
#   'region': {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Europe & Central Asia'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': 'Prague',
#   'id': 'CZE',
#   'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#   'iso2Code': 'CZ',
#   'latitude': '50.0878',
#   'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#   'longitude': '14.4205',
#   'name': 'Czech Republic',
#   'region': {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Europe & Central Asia'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'DEA',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': 'D4',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'East Asia & Pacific (IDA-eligible countries)',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'DEC',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': 'D7',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'Europe & Central Asia (IDA-eligible countries)',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': 'Berlin',
#   'id': 'DEU',
#   'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#   'iso2Code': 'DE',
#   'latitude': '52.5235',
#   'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#   'longitude': '13.4115',
#   'name': 'Germany',
#   'region': {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Europe & Central Asia'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'DFS',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': 'D8',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'IDA countries classified as Fragile Situations',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': 'MNA',
#                   'iso2code': 'XQ',
#                   'value': 'Middle East & North Africa (excluding high '
#                            'income)'},
#   'capitalCity': 'Djibouti',
#   'id': 'DJI',
#   'incomeLevel': {'id': 'LMC',
#                   'iso2code': 'XN',
#                   'value': 'Lower middle income'},
#   'iso2Code': 'DJ',
#   'latitude': '11.5806',
#   'lendingType': {'id': 'IDX', 'iso2code': 'XI', 'value': 'IDA'},
#   'longitude': '43.1425',
#   'name': 'Djibouti',
#   'region': {'id': 'MEA',
#              'iso2code': 'ZQ',
#              'value': 'Middle East & North Africa'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'DLA',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': 'D2',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'Latin America & the Caribbean (IDA-eligible countries)',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': 'LAC',
#                   'iso2code': 'XJ',
#                   'value': 'Latin America & Caribbean (excluding high income)'},
#   'capitalCity': 'Roseau',
#   'id': 'DMA',
#   'incomeLevel': {'id': 'UMC',
#                   'iso2code': 'XT',
#                   'value': 'Upper middle income'},
#   'iso2Code': 'DM',
#   'latitude': '15.2976',
#   'lendingType': {'id': 'IDB', 'iso2code': 'XH', 'value': 'Blend'},
#   'longitude': '-61.39',
#   'name': 'Dominica',
#   'region': {'id': 'LCN',
#              'iso2code': 'ZJ',
#              'value': 'Latin America & Caribbean '}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'DMN',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': 'D3',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'Middle East & North Africa (IDA-eligible countries)',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'DNF',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': 'D9',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'IDA countries not classified as Fragile Situations',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': 'Copenhagen',
#   'id': 'DNK',
#   'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#   'iso2Code': 'DK',
#   'latitude': '55.6763',
#   'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#   'longitude': '12.5681',
#   'name': 'Denmark',
#   'region': {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Europe & Central Asia'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'DNS',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': 'N6',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'IDA countries in Sub-Saharan Africa not classified as fragile '
#           'situations ',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': 'LAC',
#                   'iso2code': 'XJ',
#                   'value': 'Latin America & Caribbean (excluding high income)'},
#   'capitalCity': 'Santo Domingo',
#   'id': 'DOM',
#   'incomeLevel': {'id': 'UMC',
#                   'iso2code': 'XT',
#                   'value': 'Upper middle income'},
#   'iso2Code': 'DO',
#   'latitude': '18.479',
#   'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#   'longitude': '-69.8908',
#   'name': 'Dominican Republic',
#   'region': {'id': 'LCN',
#              'iso2code': 'ZJ',
#              'value': 'Latin America & Caribbean '}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'DSA',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': 'D5',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'South Asia (IDA-eligible countries)',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'DSF',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': 'F6',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'IDA countries in Sub-Saharan Africa classified as fragile '
#           'situations ',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'DSS',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': 'D6',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'Sub-Saharan Africa (IDA-eligible countries)',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'DXS',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': '6D',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'IDA total, excluding Sub-Saharan Africa',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': 'MNA',
#                   'iso2code': 'XQ',
#                   'value': 'Middle East & North Africa (excluding high '
#                            'income)'},
#   'capitalCity': 'Algiers',
#   'id': 'DZA',
#   'incomeLevel': {'id': 'UMC',
#                   'iso2code': 'XT',
#                   'value': 'Upper middle income'},
#   'iso2Code': 'DZ',
#   'latitude': '36.7397',
#   'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#   'longitude': '3.05097',
#   'name': 'Algeria',
#   'region': {'id': 'MEA',
#              'iso2code': 'ZQ',
#              'value': 'Middle East & North Africa'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'EAP',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': '4E',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'East Asia & Pacific (excluding high income)',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'EAR',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': 'V2',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'Early-demographic dividend',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'EAS',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': 'Z4',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'East Asia & Pacific',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'ECA',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': '7E',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'Europe & Central Asia (excluding high income)',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'ECS',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': 'Z7',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'Europe & Central Asia',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': 'LAC',
#                   'iso2code': 'XJ',
#                   'value': 'Latin America & Caribbean (excluding high income)'},
#   'capitalCity': 'Quito',
#   'id': 'ECU',
#   'incomeLevel': {'id': 'UMC',
#                   'iso2code': 'XT',
#                   'value': 'Upper middle income'},
#   'iso2Code': 'EC',
#   'latitude': '-0.229498',
#   'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#   'longitude': '-78.5243',
#   'name': 'Ecuador',
#   'region': {'id': 'LCN',
#              'iso2code': 'ZJ',
#              'value': 'Latin America & Caribbean '}},
#  {'adminregion': {'id': 'MNA',
#                   'iso2code': 'XQ',
#                   'value': 'Middle East & North Africa (excluding high '
#                            'income)'},
#   'capitalCity': 'Cairo',
#   'id': 'EGY',
#   'incomeLevel': {'id': 'LMC',
#                   'iso2code': 'XN',
#                   'value': 'Lower middle income'},
#   'iso2Code': 'EG',
#   'latitude': '30.0982',
#   'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#   'longitude': '31.2461',
#   'name': 'Egypt, Arab Rep.',
#   'region': {'id': 'MEA',
#              'iso2code': 'ZQ',
#              'value': 'Middle East & North Africa'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'EMU',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': 'XC',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'Euro area',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': 'SSA',
#                   'iso2code': 'ZF',
#                   'value': 'Sub-Saharan Africa (excluding high income)'},
#   'capitalCity': 'Asmara',
#   'id': 'ERI',
#   'incomeLevel': {'id': 'LIC', 'iso2code': 'XM', 'value': 'Low income'},
#   'iso2Code': 'ER',
#   'latitude': '15.3315',
#   'lendingType': {'id': 'IDX', 'iso2code': 'XI', 'value': 'IDA'},
#   'longitude': '38.9183',
#   'name': 'Eritrea',
#   'region': {'id': 'SSF', 'iso2code': 'ZG', 'value': 'Sub-Saharan Africa '}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': 'Madrid',
#   'id': 'ESP',
#   'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#   'iso2Code': 'ES',
#   'latitude': '40.4167',
#   'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#   'longitude': '-3.70327',
#   'name': 'Spain',
#   'region': {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Europe & Central Asia'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': 'Tallinn',
#   'id': 'EST',
#   'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#   'iso2Code': 'EE',
#   'latitude': '59.4392',
#   'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#   'longitude': '24.7586',
#   'name': 'Estonia',
#   'region': {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Europe & Central Asia'}},
#  {'adminregion': {'id': 'SSA',
#                   'iso2code': 'ZF',
#                   'value': 'Sub-Saharan Africa (excluding high income)'},
#   'capitalCity': 'Addis Ababa',
#   'id': 'ETH',
#   'incomeLevel': {'id': 'LIC', 'iso2code': 'XM', 'value': 'Low income'},
#   'iso2Code': 'ET',
#   'latitude': '9.02274',
#   'lendingType': {'id': 'IDX', 'iso2code': 'XI', 'value': 'IDA'},
#   'longitude': '38.7468',
#   'name': 'Ethiopia',
#   'region': {'id': 'SSF', 'iso2code': 'ZG', 'value': 'Sub-Saharan Africa '}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'EUU',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': 'EU',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'European Union',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'FCS',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': 'F1',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'Fragile and conflict affected situations',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': 'Helsinki',
#   'id': 'FIN',
#   'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#   'iso2Code': 'FI',
#   'latitude': '60.1608',
#   'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#   'longitude': '24.9525',
#   'name': 'Finland',
#   'region': {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Europe & Central Asia'}},
#  {'adminregion': {'id': 'EAP',
#                   'iso2code': '4E',
#                   'value': 'East Asia & Pacific (excluding high income)'},
#   'capitalCity': 'Suva',
#   'id': 'FJI',
#   'incomeLevel': {'id': 'UMC',
#                   'iso2code': 'XT',
#                   'value': 'Upper middle income'},
#   'iso2Code': 'FJ',
#   'latitude': '-18.1149',
#   'lendingType': {'id': 'IDB', 'iso2code': 'XH', 'value': 'Blend'},
#   'longitude': '178.399',
#   'name': 'Fiji',
#   'region': {'id': 'EAS', 'iso2code': 'Z4', 'value': 'East Asia & Pacific'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': 'Paris',
#   'id': 'FRA',
#   'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#   'iso2Code': 'FR',
#   'latitude': '48.8566',
#   'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#   'longitude': '2.35097',
#   'name': 'France',
#   'region': {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Europe & Central Asia'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': 'Torshavn',
#   'id': 'FRO',
#   'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#   'iso2Code': 'FO',
#   'latitude': '61.8926',
#   'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#   'longitude': '-6.91181',
#   'name': 'Faroe Islands',
#   'region': {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Europe & Central Asia'}},
#  {'adminregion': {'id': 'EAP',
#                   'iso2code': '4E',
#                   'value': 'East Asia & Pacific (excluding high income)'},
#   'capitalCity': 'Palikir',
#   'id': 'FSM',
# ...
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'TLA',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': 'T2',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'Latin America & the Caribbean (IDA & IBRD countries)',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': 'EAP',
#                   'iso2code': '4E',
#                   'value': 'East Asia & Pacific (excluding high income)'},
#   'capitalCity': 'Dili',
#   'id': 'TLS',
#   'incomeLevel': {'id': 'LMC',
#                   'iso2code': 'XN',
#                   'value': 'Lower middle income'},
#   'iso2Code': 'TL',
#   'latitude': '-8.56667',
#   'lendingType': {'id': 'IDB', 'iso2code': 'XH', 'value': 'Blend'},
#   'longitude': '125.567',
#   'name': 'Timor-Leste',
#   'region': {'id': 'EAS', 'iso2code': 'Z4', 'value': 'East Asia & Pacific'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'TMN',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': 'T3',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'Middle East & North Africa (IDA & IBRD countries)',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': 'EAP',
#                   'iso2code': '4E',
#                   'value': 'East Asia & Pacific (excluding high income)'},
#   'capitalCity': "Nuku'alofa",
#   'id': 'TON',
#   'incomeLevel': {'id': 'UMC',
#                   'iso2code': 'XT',
#                   'value': 'Upper middle income'},
#   'iso2Code': 'TO',
#   'latitude': '-21.136',
#   'lendingType': {'id': 'IDX', 'iso2code': 'XI', 'value': 'IDA'},
#   'longitude': '-175.216',
#   'name': 'Tonga',
#   'region': {'id': 'EAS', 'iso2code': 'Z4', 'value': 'East Asia & Pacific'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'TSA',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': 'T5',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'South Asia (IDA & IBRD)',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'TSS',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': 'T6',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'Sub-Saharan Africa (IDA & IBRD countries)',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': 'Port-of-Spain',
#   'id': 'TTO',
#   'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#   'iso2Code': 'TT',
#   'latitude': '10.6596',
#   'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#   'longitude': '-61.4789',
#   'name': 'Trinidad and Tobago',
#   'region': {'id': 'LCN',
#              'iso2code': 'ZJ',
#              'value': 'Latin America & Caribbean '}},
#  {'adminregion': {'id': 'MNA',
#                   'iso2code': 'XQ',
#                   'value': 'Middle East & North Africa (excluding high '
#                            'income)'},
#   'capitalCity': 'Tunis',
#   'id': 'TUN',
#   'incomeLevel': {'id': 'LMC',
#                   'iso2code': 'XN',
#                   'value': 'Lower middle income'},
#   'iso2Code': 'TN',
#   'latitude': '36.7899',
#   'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#   'longitude': '10.21',
#   'name': 'Tunisia',
#   'region': {'id': 'MEA',
#              'iso2code': 'ZQ',
#              'value': 'Middle East & North Africa'}},
#  {'adminregion': {'id': 'ECA',
#                   'iso2code': '7E',
#                   'value': 'Europe & Central Asia (excluding high income)'},
#   'capitalCity': 'Ankara',
#   'id': 'TUR',
#   'incomeLevel': {'id': 'UMC',
#                   'iso2code': 'XT',
#                   'value': 'Upper middle income'},
#   'iso2Code': 'TR',
#   'latitude': '39.7153',
#   'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#   'longitude': '32.3606',
#   'name': 'Turkey',
#   'region': {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Europe & Central Asia'}},
#  {'adminregion': {'id': 'EAP',
#                   'iso2code': '4E',
#                   'value': 'East Asia & Pacific (excluding high income)'},
#   'capitalCity': 'Funafuti',
#   'id': 'TUV',
#   'incomeLevel': {'id': 'UMC',
#                   'iso2code': 'XT',
#                   'value': 'Upper middle income'},
#   'iso2Code': 'TV',
#   'latitude': '-8.6314877',
#   'lendingType': {'id': 'IDX', 'iso2code': 'XI', 'value': 'IDA'},
#   'longitude': '179.089567',
#   'name': 'Tuvalu',
#   'region': {'id': 'EAS', 'iso2code': 'Z4', 'value': 'East Asia & Pacific'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'TWN',
#   'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#   'iso2Code': 'TW',
#   'latitude': '',
#   'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#   'longitude': '',
#   'name': 'Taiwan, China',
#   'region': {'id': 'EAS', 'iso2code': 'Z4', 'value': 'East Asia & Pacific'}},
#  {'adminregion': {'id': 'SSA',
#                   'iso2code': 'ZF',
#                   'value': 'Sub-Saharan Africa (excluding high income)'},
#   'capitalCity': 'Dodoma',
#   'id': 'TZA',
#   'incomeLevel': {'id': 'LIC', 'iso2code': 'XM', 'value': 'Low income'},
#   'iso2Code': 'TZ',
#   'latitude': '-6.17486',
#   'lendingType': {'id': 'IDX', 'iso2code': 'XI', 'value': 'IDA'},
#   'longitude': '35.7382',
#   'name': 'Tanzania',
#   'region': {'id': 'SSF', 'iso2code': 'ZG', 'value': 'Sub-Saharan Africa '}},
#  {'adminregion': {'id': 'SSA',
#                   'iso2code': 'ZF',
#                   'value': 'Sub-Saharan Africa (excluding high income)'},
#   'capitalCity': 'Kampala',
#   'id': 'UGA',
#   'incomeLevel': {'id': 'LIC', 'iso2code': 'XM', 'value': 'Low income'},
#   'iso2Code': 'UG',
#   'latitude': '0.314269',
#   'lendingType': {'id': 'IDX', 'iso2code': 'XI', 'value': 'IDA'},
#   'longitude': '32.5729',
#   'name': 'Uganda',
#   'region': {'id': 'SSF', 'iso2code': 'ZG', 'value': 'Sub-Saharan Africa '}},
#  {'adminregion': {'id': 'ECA',
#                   'iso2code': '7E',
#                   'value': 'Europe & Central Asia (excluding high income)'},
#   'capitalCity': 'Kiev',
#   'id': 'UKR',
#   'incomeLevel': {'id': 'LMC',
#                   'iso2code': 'XN',
#                   'value': 'Lower middle income'},
#   'iso2Code': 'UA',
#   'latitude': '50.4536',
#   'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#   'longitude': '30.5038',
#   'name': 'Ukraine',
#   'region': {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Europe & Central Asia'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'UMC',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': 'XT',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'Upper middle income',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': 'Montevideo',
#   'id': 'URY',
#   'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#   'iso2Code': 'UY',
#   'latitude': '-34.8941',
#   'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#   'longitude': '-56.0675',
#   'name': 'Uruguay',
#   'region': {'id': 'LCN',
#              'iso2code': 'ZJ',
#              'value': 'Latin America & Caribbean '}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': 'Washington D.C.',
#   'id': 'USA',
#   'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#   'iso2Code': 'US',
#   'latitude': '38.8895',
#   'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#   'longitude': '-77.032',
#   'name': 'United States',
#   'region': {'id': 'NAC', 'iso2code': 'XU', 'value': 'North America'}},
#  {'adminregion': {'id': 'ECA',
#                   'iso2code': '7E',
#                   'value': 'Europe & Central Asia (excluding high income)'},
#   'capitalCity': 'Tashkent',
#   'id': 'UZB',
#   'incomeLevel': {'id': 'LMC',
#                   'iso2code': 'XN',
#                   'value': 'Lower middle income'},
#   'iso2Code': 'UZ',
#   'latitude': '41.3052',
#   'lendingType': {'id': 'IDB', 'iso2code': 'XH', 'value': 'Blend'},
#   'longitude': '69.269',
#   'name': 'Uzbekistan',
#   'region': {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Europe & Central Asia'}},
#  {'adminregion': {'id': 'LAC',
#                   'iso2code': 'XJ',
#                   'value': 'Latin America & Caribbean (excluding high income)'},
#   'capitalCity': 'Kingstown',
#   'id': 'VCT',
#   'incomeLevel': {'id': 'UMC',
#                   'iso2code': 'XT',
#                   'value': 'Upper middle income'},
#   'iso2Code': 'VC',
#   'latitude': '13.2035',
#   'lendingType': {'id': 'IDB', 'iso2code': 'XH', 'value': 'Blend'},
#   'longitude': '-61.2653',
#   'name': 'St. Vincent and the Grenadines',
#   'region': {'id': 'LCN',
#              'iso2code': 'ZJ',
#              'value': 'Latin America & Caribbean '}},
#  {'adminregion': {'id': 'LAC',
#                   'iso2code': 'XJ',
#                   'value': 'Latin America & Caribbean (excluding high income)'},
#   'capitalCity': 'Caracas',
#   'id': 'VEN',
#   'incomeLevel': {'id': 'UMC',
#                   'iso2code': 'XT',
#                   'value': 'Upper middle income'},
#   'iso2Code': 'VE',
#   'latitude': '9.08165',
#   'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#   'longitude': '-69.8371',
#   'name': 'Venezuela, RB',
#   'region': {'id': 'LCN',
#              'iso2code': 'ZJ',
#              'value': 'Latin America & Caribbean '}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': 'Road Town',
#   'id': 'VGB',
#   'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#   'iso2Code': 'VG',
#   'latitude': '18.431389',
#   'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#   'longitude': '-64.623056',
#   'name': 'British Virgin Islands',
#   'region': {'id': 'LCN',
#              'iso2code': 'ZJ',
#              'value': 'Latin America & Caribbean '}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': 'Charlotte Amalie',
#   'id': 'VIR',
#   'incomeLevel': {'id': 'HIC', 'iso2code': 'XD', 'value': 'High income'},
#   'iso2Code': 'VI',
#   'latitude': '18.3358',
#   'lendingType': {'id': 'LNX', 'iso2code': 'XX', 'value': 'Not classified'},
#   'longitude': '-64.8963',
#   'name': 'Virgin Islands (U.S.)',
#   'region': {'id': 'LCN',
#              'iso2code': 'ZJ',
#              'value': 'Latin America & Caribbean '}},
#  {'adminregion': {'id': 'EAP',
#                   'iso2code': '4E',
#                   'value': 'East Asia & Pacific (excluding high income)'},
#   'capitalCity': 'Hanoi',
#   'id': 'VNM',
#   'incomeLevel': {'id': 'LMC',
#                   'iso2code': 'XN',
#                   'value': 'Lower middle income'},
#   'iso2Code': 'VN',
#   'latitude': '21.0069',
#   'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#   'longitude': '105.825',
#   'name': 'Vietnam',
#   'region': {'id': 'EAS', 'iso2code': 'Z4', 'value': 'East Asia & Pacific'}},
#  {'adminregion': {'id': 'EAP',
#                   'iso2code': '4E',
#                   'value': 'East Asia & Pacific (excluding high income)'},
#   'capitalCity': 'Port-Vila',
#   'id': 'VUT',
#   'incomeLevel': {'id': 'LMC',
#                   'iso2code': 'XN',
#                   'value': 'Lower middle income'},
#   'iso2Code': 'VU',
#   'latitude': '-17.7404',
#   'lendingType': {'id': 'IDX', 'iso2code': 'XI', 'value': 'IDA'},
#   'longitude': '168.321',
#   'name': 'Vanuatu',
#   'region': {'id': 'EAS', 'iso2code': 'Z4', 'value': 'East Asia & Pacific'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'WLD',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': '1W',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'World',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': 'EAP',
#                   'iso2code': '4E',
#                   'value': 'East Asia & Pacific (excluding high income)'},
#   'capitalCity': 'Apia',
#   'id': 'WSM',
#   'incomeLevel': {'id': 'UMC',
#                   'iso2code': 'XT',
#                   'value': 'Upper middle income'},
#   'iso2Code': 'WS',
#   'latitude': '-13.8314',
#   'lendingType': {'id': 'IDX', 'iso2code': 'XI', 'value': 'IDA'},
#   'longitude': '-171.752',
#   'name': 'Samoa',
#   'region': {'id': 'EAS', 'iso2code': 'Z4', 'value': 'East Asia & Pacific'}},
#  {'adminregion': {'id': 'ECA',
#                   'iso2code': '7E',
#                   'value': 'Europe & Central Asia (excluding high income)'},
#   'capitalCity': 'Pristina',
#   'id': 'XKX',
#   'incomeLevel': {'id': 'UMC',
#                   'iso2code': 'XT',
#                   'value': 'Upper middle income'},
#   'iso2Code': 'XK',
#   'latitude': '42.565',
#   'lendingType': {'id': 'IDX', 'iso2code': 'XI', 'value': 'IDA'},
#   'longitude': '20.926',
#   'name': 'Kosovo',
#   'region': {'id': 'ECS', 'iso2code': 'Z7', 'value': 'Europe & Central Asia'}},
#  {'adminregion': {'id': '', 'iso2code': '', 'value': ''},
#   'capitalCity': '',
#   'id': 'XZN',
#   'incomeLevel': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'},
#   'iso2Code': 'A5',
#   'latitude': '',
#   'lendingType': {'id': '', 'iso2code': '', 'value': 'Aggregates'},
#   'longitude': '',
#   'name': 'Sub-Saharan Africa excluding South Africa and Nigeria',
#   'region': {'id': 'NA', 'iso2code': 'NA', 'value': 'Aggregates'}},
#  {'adminregion': {'id': 'MNA',
#                   'iso2code': 'XQ',
#                   'value': 'Middle East & North Africa (excluding high '
#                            'income)'},
#   'capitalCity': "Sana'a",
#   'id': 'YEM',
#   'incomeLevel': {'id': 'LIC', 'iso2code': 'XM', 'value': 'Low income'},
#   'iso2Code': 'YE',
#   'latitude': '15.352',
#   'lendingType': {'id': 'IDX', 'iso2code': 'XI', 'value': 'IDA'},
#   'longitude': '44.2075',
#   'name': 'Yemen, Rep.',
#   'region': {'id': 'MEA',
#              'iso2code': 'ZQ',
#              'value': 'Middle East & North Africa'}},
#  {'adminregion': {'id': 'SSA',
#                   'iso2code': 'ZF',
#                   'value': 'Sub-Saharan Africa (excluding high income)'},
#   'capitalCity': 'Pretoria',
#   'id': 'ZAF',
#   'incomeLevel': {'id': 'UMC',
#                   'iso2code': 'XT',
#                   'value': 'Upper middle income'},
#   'iso2Code': 'ZA',
#   'latitude': '-25.746',
#   'lendingType': {'id': 'IBD', 'iso2code': 'XF', 'value': 'IBRD'},
#   'longitude': '28.1871',
#   'name': 'South Africa',
#   'region': {'id': 'SSF', 'iso2code': 'ZG', 'value': 'Sub-Saharan Africa '}},
#  {'adminregion': {'id': 'SSA',
#                   'iso2code': 'ZF',
#                   'value': 'Sub-Saharan Africa (excluding high income)'},
#   'capitalCity': 'Lusaka',
#   'id': 'ZMB',
#   'incomeLevel': {'id': 'LMC',
#                   'iso2code': 'XN',
#                   'value': 'Lower middle income'},
#   'iso2Code': 'ZM',
#   'latitude': '-15.3982',
#   'lendingType': {'id': 'IDX', 'iso2code': 'XI', 'value': 'IDA'},
#   'longitude': '28.2937',
#   'name': 'Zambia',
#   'region': {'id': 'SSF', 'iso2code': 'ZG', 'value': 'Sub-Saharan Africa '}},
#  {'adminregion': {'id': 'SSA',
#                   'iso2code': 'ZF',
#                   'value': 'Sub-Saharan Africa (excluding high income)'},
#   'capitalCity': 'Harare',
#   'id': 'ZWE',
#   'incomeLevel': {'id': 'LMC',
#                   'iso2code': 'XN',
#                   'value': 'Lower middle income'},
#   'iso2Code': 'ZW',
#   'latitude': '-17.8312',
#   'lendingType': {'id': 'IDB', 'iso2code': 'XH', 'value': 'Blend'},
#   'longitude': '31.0672',
#   'name': 'Zimbabwe',
#   'region': {'id': 'SSF', 'iso2code': 'ZG', 'value': 'Sub-Saharan Africa '}}]

# %%
# read csv file from specified folder
country_gdp_df = pd.read_csv(country_gdp_file)
country_pop_df = pd.read_csv(country_pop_file)

# clean up data and creating dataframe with required columns
clean_gdp_df = country_gdp_df[['Country Code', '2018_gdp']].copy()
clean_pop_df = country_pop_df[['Country Code', '2018_pop']].copy()

# replace NaN data with 0
clean_gdp_df['2018_gdp'] = clean_gdp_df['2018_gdp'].replace(np.nan, 0)
clean_pop_df['2018_pop'] = clean_pop_df['2018_pop'].replace(np.nan, 0)

# merge two dataset to one dataframe
gdp_pop_df = pd.merge(clean_gdp_df, clean_pop_df, on=['Country Code', 'Country Code'])
gdp_pop_df.head()
# Out:
#   Country Code      2018_gdp    2018_pop
# 0          ABW  0.000000e+00    105845.0
# 1          AFG  1.936297e+10  37172386.0
# 2          AGO  1.060000e+11  30809762.0
# 3          ALB  1.505888e+10   2866376.0
# 4          AND  3.236544e+09     77006.0

# %%
# define veriables

ids = []
incomeLevel = []
country = []
lat = []
lon = []
country_name = []
region = []

world_data_df = pd.DataFrame()

# append required json data
for world_data in data[1]:
    ids.append(world_data["id"])
    country_name.append(world_data["name"])
    region.append(world_data["region"]["value"])
    incomeLevel.append(world_data["incomeLevel"]["value"])
    lat.append(world_data["latitude"])
    lon.append(world_data["longitude"])
    
    
# create dataset from required fields
world_data_df["Country Code"] = ids
world_data_df["country_name"] = country_name
world_data_df["region"] = region
world_data_df["income_level"] = incomeLevel
world_data_df["latitude"] = lat
world_data_df["longitude"] = lon

# drop duplicate records
world_data_df.drop_duplicates()

# replace latitude and longitude empty value with 0
world_data_df['latitude'] = world_data_df['latitude'].replace('', 0)
world_data_df['longitude'] = world_data_df['longitude'].replace('', 0)

# merge dataframe by country code and create one data frame
world_income_df = pd.merge(world_data_df, gdp_pop_df, on=['Country Code', 'Country Code'])
world_income_df.head()
# Out:
#   Country Code country_name                      region         income_level  \
# 0          ABW        Aruba  Latin America & Caribbean           High income
# 1          AFG  Afghanistan                  South Asia           Low income
# 2          AGO       Angola         Sub-Saharan Africa   Lower middle income
# 3          ALB      Albania       Europe & Central Asia  Upper middle income
# 4          AND      Andorra       Europe & Central Asia          High income
#
#    latitude longitude      2018_gdp    2018_pop
# 0   12.5167  -70.0167  0.000000e+00    105845.0
# 1   34.5228   69.1761  1.936297e+10  37172386.0
# 2  -8.81155    13.242  1.060000e+11  30809762.0
# 3   41.3317   19.8172  1.505888e+10   2866376.0
# 4   42.5075    1.5218  3.236544e+09     77006.0

# %%
world_income_df = world_income_df.rename(columns={"2018_gdp": "gdp","2018_pop":"population"})

# %%
##world_income_df.to_csv()
# Out:
# ',Country Code,country_name,region,income_level,latitude,longitude,GDP,Population\r\n0,ABW,Aruba,Latin America & Caribbean ,High income,12.5167,-70.0167,0.0,105845.0\r\n1,AFG,Afghanistan,South Asia,Low income,34.5228,69.1761,19362969582.0,37172386.0\r\n2,AGO,Angola,Sub-Saharan Africa ,Lower middle income,-8.81155,13.242,106000000000.0,30809762.0\r\n3,ALB,Albania,Europe & Central Asia,Upper middle income,41.3317,19.8172,15058879129.0,2866376.0\r\n4,AND,Andorra,Europe & Central Asia,High income,42.5075,1.5218,3236543909.0,77006.0\r\n5,ARB,Arab World,Aggregates,Aggregates,0,0,2780000000000.0,419790588.0\r\n6,ARE,United Arab Emirates,Middle East & North Africa,High income,24.4764,54.3705,414000000000.0,9630959.0\r\n7,ARG,Argentina,Latin America & Caribbean ,Upper middle income,-34.6118,-58.4173,518000000000.0,44494502.0\r\n8,ARM,Armenia,Europe & Central Asia,Upper middle income,40.1596,44.509,12433089919.0,2951776.0\r\n9,ASM,American Samoa,East Asia & Pacific,Upper middle income,-14.2846,-170.691,0.0,55465.0\r\n10,ATG,Antigua and Barbuda,Latin America & Caribbean ,High income,17.1175,-61.8456,1623804016.0,96286.0\r\n11,AUS,Australia,East Asia & Pacific,High income,-35.282,149.129,1430000000000.0,24992369.0\r\n12,AUT,Austria,Europe & Central Asia,High income,48.2201,16.3798,456000000000.0,8847037.0\r\n13,AZE,Azerbaijan,Europe & Central Asia,Upper middle income,40.3834,49.8932,46939529412.0,9942334.0\r\n14,BDI,Burundi,Sub-Saharan Africa ,Low income,-3.3784,29.3639,3078029929.0,11175378.0\r\n15,BEL,Belgium,Europe & Central Asia,High income,50.8371,4.36761,532000000000.0,11422068.0\r\n16,BEN,Benin,Sub-Saharan Africa ,Low income,6.4779,2.6323,10358985583.0,11485048.0\r\n17,BFA,Burkina Faso,Sub-Saharan Africa ,Low income,12.3605,-1.53395,14441763759.0,19751535.0\r\n18,BGD,Bangladesh,South Asia,Lower middle income,23.7055,90.4113,274000000000.0,161356039.0\r\n19,BGR,Bulgaria,Europe & Central Asia,Upper middle income,42.7105,23.3238,65132951116.0,7024216.0\r\n20,BHR,Bahrain,Middle East & North Africa,High income,26.1921,50.5354,37746196809.0,1569439.0\r\n21,BHS,"Bahamas, The",Latin America & Caribbean ,High income,25.0661,-77.339,0.0,385640.0\r\n22,BIH,Bosnia and Herzegovina,Europe & Central Asia,Upper middle income,43.8607,18.4214,19781776101.0,3323929.0\r\n23,BLR,Belarus,Europe & Central Asia,Upper middle income,53.9678,27.5766,59662495092.0,9485386.0\r\n24,BLZ,Belize,Latin America & Caribbean ,Upper middle income,17.2534,-88.7713,1925000000.0,383071.0\r\n25,BMU,Bermuda,North America,High income,32.3293,-64.706,0.0,63968.0\r\n26,BOL,Bolivia,Latin America & Caribbean ,Lower middle income,-13.9908,-66.1936,40287647757.0,11353142.0\r\n27,BRA,Brazil,Latin America & Caribbean ,Upper middle income,-15.7801,-47.9292,1870000000000.0,209469333.0\r\n28,BRB,Barbados,Latin America & Caribbean ,High income,13.0935,-59.6105,0.0,286641.0\r\n29,BRN,Brunei Darussalam,East Asia & Pacific,High income,4.94199,114.946,13567099498.0,428962.0\r\n30,BTN,Bhutan,South Asia,Lower middle income,27.5768,89.6177,2534965163.0,754394.0\r\n31,BWA,Botswana,Sub-Saharan Africa ,Upper middle income,-24.6544,25.9201,18616018903.0,2254126.0\r\n32,CAF,Central African Republic,Sub-Saharan Africa ,Low income,5.63056,21.6407,2379716827.0,4666377.0\r\n33,CAN,Canada,North America,High income,45.4215,-75.6919,1710000000000.0,37058856.0\r\n34,CEB,Central Europe and the Baltics,Aggregates,Aggregates,0,0,1630000000000.0,102511922.0\r\n35,CHE,Switzerland,Europe & Central Asia,High income,46.948,7.44821,706000000000.0,8516543.0\r\n36,CHI,Channel Islands,Europe & Central Asia,High income,0,0,0.0,170499.0\r\n37,CHL,Chile,Latin America & Caribbean ,High income,-33.475,-70.6475,298000000000.0,18729160.0\r\n38,CHN,China,East Asia & Pacific,Upper middle income,40.0495,116.286,13600000000000.0,1392730000.0\r\n39,CIV,Cote d\'Ivoire,Sub-Saharan Africa ,Lower middle income,5.332,-4.0305,43007045466.0,25069229.0\r\n40,CMR,Cameroon,Sub-Saharan Africa ,Lower middle income,3.8721,11.5174,38502059858. ...

# %%
world_income_df
# Out:
#     Country Code                                       country_name  \
# 0            ABW                                              Aruba
# 1            AFG                                        Afghanistan
# 2            AGO                                             Angola
# 3            ALB                                            Albania
# 4            AND                                            Andorra
# 5            ARB                                         Arab World
# 6            ARE                               United Arab Emirates
# 7            ARG                                          Argentina
# 8            ARM                                            Armenia
# 9            ASM                                     American Samoa
# 10           ATG                                Antigua and Barbuda
# 11           AUS                                          Australia
# 12           AUT                                            Austria
# 13           AZE                                         Azerbaijan
# 14           BDI                                            Burundi
# 15           BEL                                            Belgium
# 16           BEN                                              Benin
# 17           BFA                                       Burkina Faso
# 18           BGD                                         Bangladesh
# 19           BGR                                           Bulgaria
# 20           BHR                                            Bahrain
# 21           BHS                                       Bahamas, The
# 22           BIH                             Bosnia and Herzegovina
# 23           BLR                                            Belarus
# 24           BLZ                                             Belize
# 25           BMU                                            Bermuda
# 26           BOL                                            Bolivia
# 27           BRA                                             Brazil
# 28           BRB                                           Barbados
# 29           BRN                                  Brunei Darussalam
# ..           ...                                                ...
# 234          TLA  Latin America & the Caribbean (IDA & IBRD coun...
# 235          TLS                                        Timor-Leste
# 236          TMN  Middle East & North Africa (IDA & IBRD countries)
# 237          TON                                              Tonga
# 238          TSA                            South Asia (IDA & IBRD)
# 239          TSS          Sub-Saharan Africa (IDA & IBRD countries)
# 240          TTO                                Trinidad and Tobago
# 241          TUN                                            Tunisia
# 242          TUR                                             Turkey
# 243          TUV                                             Tuvalu
# 244          TZA                                           Tanzania
# 245          UGA                                             Uganda
# 246          UKR                                            Ukraine
# 247          UMC                                Upper middle income
# 248          URY                                            Uruguay
# 249          USA                                      United States
# 250          UZB                                         Uzbekistan
# 251          VCT                     St. Vincent and the Grenadines
# 252          VEN                                      Venezuela, RB
# 253          VGB                             British Virgin Islands
# 254          VIR                              Virgin Islands (U.S.)
# 255          VNM                                            Vietnam
# 256          VUT                                            Vanuatu
# 257          WLD                                              World
# 258          WSM                                              Samoa
# 259          XKX                                             Kosovo
# 260          YEM                                        Yemen, Rep.
# 261          ZAF                                       South Africa
# 262          ZMB                                             Zambia
# 263          ZWE                                           Zimbabwe
#
#                          region         income_level    latitude   longitude  \
# 0    Latin America & Caribbean           High income     12.5167    -70.0167
# 1                    South Asia           Low income     34.5228     69.1761
# 2           Sub-Saharan Africa   Lower middle income    -8.81155      13.242
# 3         Europe & Central Asia  Upper middle income     41.3317     19.8172
# 4         Europe & Central Asia          High income     42.5075      1.5218
# 5                    Aggregates           Aggregates           0           0
# 6    Middle East & North Africa          High income     24.4764     54.3705
# 7    Latin America & Caribbean   Upper middle income    -34.6118    -58.4173
# 8         Europe & Central Asia  Upper middle income     40.1596      44.509
# 9           East Asia & Pacific  Upper middle income    -14.2846    -170.691
# 10   Latin America & Caribbean           High income     17.1175    -61.8456
# 11          East Asia & Pacific          High income     -35.282     149.129
# 12        Europe & Central Asia          High income     48.2201     16.3798
# 13        Europe & Central Asia  Upper middle income     40.3834     49.8932
# 14          Sub-Saharan Africa            Low income     -3.3784     29.3639
# 15        Europe & Central Asia          High income     50.8371     4.36761
# 16          Sub-Saharan Africa            Low income      6.4779      2.6323
# 17          Sub-Saharan Africa            Low income     12.3605    -1.53395
# 18                   South Asia  Lower middle income     23.7055     90.4113
# 19        Europe & Central Asia  Upper middle income     42.7105     23.3238
# 20   Middle East & North Africa          High income     26.1921     50.5354
# 21   Latin America & Caribbean           High income     25.0661     -77.339
# 22        Europe & Central Asia  Upper middle income     43.8607     18.4214
# 23        Europe & Central Asia  Upper middle income     53.9678     27.5766
# 24   Latin America & Caribbean   Upper middle income     17.2534    -88.7713
# 25                North America          High income     32.3293     -64.706
# 26   Latin America & Caribbean   Lower middle income    -13.9908    -66.1936
# 27   Latin America & Caribbean   Upper middle income    -15.7801    -47.9292
# 28   Latin America & Caribbean           High income     13.0935    -59.6105
# 29          East Asia & Pacific          High income     4.94199     114.946
# ..                          ...                  ...         ...         ...
# 234                  Aggregates           Aggregates           0           0
# 235         East Asia & Pacific  Lower middle income    -8.56667     125.567
# 236                  Aggregates           Aggregates           0           0
# 237         East Asia & Pacific  Upper middle income     -21.136    -175.216
# 238                  Aggregates           Aggregates           0           0
# 239                  Aggregates           Aggregates           0           0
# 240  Latin America & Caribbean           High income     10.6596    -61.4789
# 241  Middle East & North Africa  Lower middle income     36.7899       10.21
# 242       Europe & Central Asia  Upper middle income     39.7153     32.3606
# 243         East Asia & Pacific  Upper middle income  -8.6314877  179.089567
# 244         Sub-Saharan Africa            Low income    -6.17486     35.7382
# 245         Sub-Saharan Africa            Low income    0.314269     32.5729
# 246       Europe & Central Asia  Lower middle income     50.4536     30.5038
# 247                  Aggregates           Aggregates           0           0
# 248  Latin America & Caribbean           High income    -34.8941    -56.0675
# 249               North America          High income     38.8895     -77.032
# 250       Europe & Central Asia  Lower middle income     41.3052      69.269
# 251  Latin America & Caribbean   Upper middle income     13.2035    -61.2653
# 252  Latin America & Caribbean   Upper middle income     9.08165    -69.8371
# 253  Latin America & Caribbean           High income   18.431389  -64.623056
# 254  Latin America & Caribbean           High income     18.3358    -64.8963
# 255         East Asia & Pacific  Lower middle income     21.0069     105.825
# 256         East Asia & Pacific  Lower middle income    -17.7404     168.321
# 257                  Aggregates           Aggregates           0           0
# 258         East Asia & Pacific  Upper middle income    -13.8314    -171.752
# 259       Europe & Central Asia  Upper middle income      42.565      20.926
# 260  Middle East & North Africa           Low income      15.352     44.2075
# 261         Sub-Saharan Africa   Upper middle income     -25.746     28.1871
# 262         Sub-Saharan Africa   Lower middle income    -15.3982     28.2937
# 263         Sub-Saharan Africa   Lower middle income    -17.8312     31.0672
#
#               gdp    population
# 0    0.000000e+00  1.058450e+05
# 1    1.936297e+10  3.717239e+07
# 2    1.060000e+11  3.080976e+07
# 3    1.505888e+10  2.866376e+06
# 4    3.236544e+09  7.700600e+04
# 5    2.780000e+12  4.197906e+08
# 6    4.140000e+11  9.630959e+06
# 7    5.180000e+11  4.449450e+07
# 8    1.243309e+10  2.951776e+06
# 9    0.000000e+00  5.546500e+04
# 10   1.623804e+09  9.628600e+04
# 11   1.430000e+12  2.499237e+07
# 12   4.560000e+11  8.847037e+06
# 13   4.693953e+10  9.942334e+06
# 14   3.078030e+09  1.117538e+07
# 15   5.320000e+11  1.142207e+07
# 16   1.035899e+10  1.148505e+07
# 17   1.444176e+10  1.975154e+07
# 18   2.740000e+11  1.613560e+08
# 19   6.513295e+10  7.024216e+06
# 20   3.774620e+10  1.569439e+06
# 21   0.000000e+00  3.856400e+05
# 22   1.978178e+10  3.323929e+06
# 23   5.966250e+10  9.485386e+06
# 24   1.925000e+09  3.830710e+05
# 25   0.000000e+00  6.396800e+04
# 26   4.028765e+10  1.135314e+07
# 27   1.870000e+12  2.094693e+08
# 28   0.000000e+00  2.866410e+05
# 29   1.356710e+10  4.289620e+05
# ..            ...           ...
# 234  5.560000e+12  6.255697e+08
# 235  2.581000e+09  1.267972e+06
# 236  0.000000e+00  3.783276e+08
# 237  4.503533e+08  1.031970e+05
# 238  3.460000e+12  1.814389e+09
# 239  1.700000e+12  1.078307e+09
# 240  2.341035e+10  1.389858e+06
# 241  3.986072e+10  1.156520e+07
# 242  7.670000e+11  8.231972e+07
# 243  4.258778e+07  1.150800e+04
# 244  5.743707e+10  5.631835e+07
# 245  2.747695e+10  4.272314e+07
# 246  1.310000e+11  4.462252e+07
# 247  2.440000e+13  2.655636e+09
# 248  5.959689e+10  3.449299e+06
# 249  2.050000e+13  3.271674e+08
# 250  5.049992e+10  3.295540e+07
# 251  8.130940e+08  1.102100e+05
# 252  0.000000e+00  2.887020e+07
# 253  0.000000e+00  2.980200e+04
# 254  0.000000e+00  1.069770e+05
# 255  2.450000e+11  9.554040e+07
# 256  8.878179e+08  2.926800e+05
# 257  8.580000e+13  7.594270e+09
# 258  8.614947e+08  1.961300e+05
# 259  7.900269e+09  1.845300e+06
# 260  2.691440e+10  2.849869e+07
# 261  3.660000e+11  5.777962e+07
# 262  2.672007e+10  1.735182e+07
# 263  3.100052e+10  1.443902e+07
#
# [264 rows x 8 columns]

# %%
# Create connection to local database
rds_connection_string = "postgres:postgres@127.0.0.1:5432/world_income_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
# Get table name available on database
engine.table_names()
# Out:
# ['world_income']

# %%
# insert dataframe data to world_income table
world_income_df.to_sql(name='world_income', con=engine, if_exists='append', index=False)

# %%
# get data from world_income table
pd.read_sql_query('select * from world_income', con=engine).head()
# Out:
#   Country Code country_name                      region         income_level  \
# 0          ABW        Aruba  Latin America & Caribbean           High income
# 1          AFG  Afghanistan                  South Asia           Low income
# 2          AGO       Angola         Sub-Saharan Africa   Lower middle income
# 3          ALB      Albania       Europe & Central Asia  Upper middle income
# 4          AND      Andorra       Europe & Central Asia          High income
#
#    latitude  longitude           gdp  population
# 0  12.51670   -70.0167  0.000000e+00    105845.0
# 1  34.52280    69.1761  1.936297e+10  37172386.0
# 2  -8.81155    13.2420  1.060000e+11  30809762.0
# 3  41.33170    19.8172  1.505888e+10   2866376.0
# 4  42.50750     1.5218  3.236544e+09     77006.0

# %%
world_income_df = pd.read_sql_query('select * from world_income', con=engine)

# %%
world_income_df
# Out:
#     Country Code                                       country_name  \
# 0            ABW                                              Aruba
# 1            AFG                                        Afghanistan
# 2            AGO                                             Angola
# 3            ALB                                            Albania
# 4            AND                                            Andorra
# 5            ARB                                         Arab World
# 6            ARE                               United Arab Emirates
# 7            ARG                                          Argentina
# 8            ARM                                            Armenia
# 9            ASM                                     American Samoa
# 10           ATG                                Antigua and Barbuda
# 11           AUS                                          Australia
# 12           AUT                                            Austria
# 13           AZE                                         Azerbaijan
# 14           BDI                                            Burundi
# 15           BEL                                            Belgium
# 16           BEN                                              Benin
# 17           BFA                                       Burkina Faso
# 18           BGD                                         Bangladesh
# 19           BGR                                           Bulgaria
# 20           BHR                                            Bahrain
# 21           BHS                                       Bahamas, The
# 22           BIH                             Bosnia and Herzegovina
# 23           BLR                                            Belarus
# 24           BLZ                                             Belize
# 25           BMU                                            Bermuda
# 26           BOL                                            Bolivia
# 27           BRA                                             Brazil
# 28           BRB                                           Barbados
# 29           BRN                                  Brunei Darussalam
# ..           ...                                                ...
# 234          TLA  Latin America & the Caribbean (IDA & IBRD coun...
# 235          TLS                                        Timor-Leste
# 236          TMN  Middle East & North Africa (IDA & IBRD countries)
# 237          TON                                              Tonga
# 238          TSA                            South Asia (IDA & IBRD)
# 239          TSS          Sub-Saharan Africa (IDA & IBRD countries)
# 240          TTO                                Trinidad and Tobago
# 241          TUN                                            Tunisia
# 242          TUR                                             Turkey
# 243          TUV                                             Tuvalu
# 244          TZA                                           Tanzania
# 245          UGA                                             Uganda
# 246          UKR                                            Ukraine
# 247          UMC                                Upper middle income
# 248          URY                                            Uruguay
# 249          USA                                      United States
# 250          UZB                                         Uzbekistan
# 251          VCT                     St. Vincent and the Grenadines
# 252          VEN                                      Venezuela, RB
# 253          VGB                             British Virgin Islands
# 254          VIR                              Virgin Islands (U.S.)
# 255          VNM                                            Vietnam
# 256          VUT                                            Vanuatu
# 257          WLD                                              World
# 258          WSM                                              Samoa
# 259          XKX                                             Kosovo
# 260          YEM                                        Yemen, Rep.
# 261          ZAF                                       South Africa
# 262          ZMB                                             Zambia
# 263          ZWE                                           Zimbabwe
#
#                          region         income_level    latitude   longitude  \
# 0    Latin America & Caribbean           High income     12.5167    -70.0167
# 1                    South Asia           Low income     34.5228     69.1761
# 2           Sub-Saharan Africa   Lower middle income    -8.81155      13.242
# 3         Europe & Central Asia  Upper middle income     41.3317     19.8172
# 4         Europe & Central Asia          High income     42.5075      1.5218
# 5                    Aggregates           Aggregates           0           0
# 6    Middle East & North Africa          High income     24.4764     54.3705
# 7    Latin America & Caribbean   Upper middle income    -34.6118    -58.4173
# 8         Europe & Central Asia  Upper middle income     40.1596      44.509
# 9           East Asia & Pacific  Upper middle income    -14.2846    -170.691
# 10   Latin America & Caribbean           High income     17.1175    -61.8456
# 11          East Asia & Pacific          High income     -35.282     149.129
# 12        Europe & Central Asia          High income     48.2201     16.3798
# 13        Europe & Central Asia  Upper middle income     40.3834     49.8932
# 14          Sub-Saharan Africa            Low income     -3.3784     29.3639
# 15        Europe & Central Asia          High income     50.8371     4.36761
# 16          Sub-Saharan Africa            Low income      6.4779      2.6323
# 17          Sub-Saharan Africa            Low income     12.3605    -1.53395
# 18                   South Asia  Lower middle income     23.7055     90.4113
# 19        Europe & Central Asia  Upper middle income     42.7105     23.3238
# 20   Middle East & North Africa          High income     26.1921     50.5354
# 21   Latin America & Caribbean           High income     25.0661     -77.339
# 22        Europe & Central Asia  Upper middle income     43.8607     18.4214
# 23        Europe & Central Asia  Upper middle income     53.9678     27.5766
# 24   Latin America & Caribbean   Upper middle income     17.2534    -88.7713
# 25                North America          High income     32.3293     -64.706
# 26   Latin America & Caribbean   Lower middle income    -13.9908    -66.1936
# 27   Latin America & Caribbean   Upper middle income    -15.7801    -47.9292
# 28   Latin America & Caribbean           High income     13.0935    -59.6105
# 29          East Asia & Pacific          High income     4.94199     114.946
# ..                          ...                  ...         ...         ...
# 234                  Aggregates           Aggregates           0           0
# 235         East Asia & Pacific  Lower middle income    -8.56667     125.567
# 236                  Aggregates           Aggregates           0           0
# 237         East Asia & Pacific  Upper middle income     -21.136    -175.216
# 238                  Aggregates           Aggregates           0           0
# 239                  Aggregates           Aggregates           0           0
# 240  Latin America & Caribbean           High income     10.6596    -61.4789
# 241  Middle East & North Africa  Lower middle income     36.7899       10.21
# 242       Europe & Central Asia  Upper middle income     39.7153     32.3606
# 243         East Asia & Pacific  Upper middle income  -8.6314877  179.089567
# 244         Sub-Saharan Africa            Low income    -6.17486     35.7382
# 245         Sub-Saharan Africa            Low income    0.314269     32.5729
# 246       Europe & Central Asia  Lower middle income     50.4536     30.5038
# 247                  Aggregates           Aggregates           0           0
# 248  Latin America & Caribbean           High income    -34.8941    -56.0675
# 249               North America          High income     38.8895     -77.032
# 250       Europe & Central Asia  Lower middle income     41.3052      69.269
# 251  Latin America & Caribbean   Upper middle income     13.2035    -61.2653
# 252  Latin America & Caribbean   Upper middle income     9.08165    -69.8371
# 253  Latin America & Caribbean           High income   18.431389  -64.623056
# 254  Latin America & Caribbean           High income     18.3358    -64.8963
# 255         East Asia & Pacific  Lower middle income     21.0069     105.825
# 256         East Asia & Pacific  Lower middle income    -17.7404     168.321
# 257                  Aggregates           Aggregates           0           0
# 258         East Asia & Pacific  Upper middle income    -13.8314    -171.752
# 259       Europe & Central Asia  Upper middle income      42.565      20.926
# 260  Middle East & North Africa           Low income      15.352     44.2075
# 261         Sub-Saharan Africa   Upper middle income     -25.746     28.1871
# 262         Sub-Saharan Africa   Lower middle income    -15.3982     28.2937
# 263         Sub-Saharan Africa   Lower middle income    -17.8312     31.0672
#
#               gdp    population
# 0    0.000000e+00  1.058450e+05
# 1    1.936297e+10  3.717239e+07
# 2    1.060000e+11  3.080976e+07
# 3    1.505888e+10  2.866376e+06
# 4    3.236544e+09  7.700600e+04
# 5    2.780000e+12  4.197906e+08
# 6    4.140000e+11  9.630959e+06
# 7    5.180000e+11  4.449450e+07
# 8    1.243309e+10  2.951776e+06
# 9    0.000000e+00  5.546500e+04
# 10   1.623804e+09  9.628600e+04
# 11   1.430000e+12  2.499237e+07
# 12   4.560000e+11  8.847037e+06
# 13   4.693953e+10  9.942334e+06
# 14   3.078030e+09  1.117538e+07
# 15   5.320000e+11  1.142207e+07
# 16   1.035899e+10  1.148505e+07
# 17   1.444176e+10  1.975154e+07
# 18   2.740000e+11  1.613560e+08
# 19   6.513295e+10  7.024216e+06
# 20   3.774620e+10  1.569439e+06
# 21   0.000000e+00  3.856400e+05
# 22   1.978178e+10  3.323929e+06
# 23   5.966250e+10  9.485386e+06
# 24   1.925000e+09  3.830710e+05
# 25   0.000000e+00  6.396800e+04
# 26   4.028765e+10  1.135314e+07
# 27   1.870000e+12  2.094693e+08
# 28   0.000000e+00  2.866410e+05
# 29   1.356710e+10  4.289620e+05
# ..            ...           ...
# 234  5.560000e+12  6.255697e+08
# 235  2.581000e+09  1.267972e+06
# 236  0.000000e+00  3.783276e+08
# 237  4.503533e+08  1.031970e+05
# 238  3.460000e+12  1.814389e+09
# 239  1.700000e+12  1.078307e+09
# 240  2.341035e+10  1.389858e+06
# 241  3.986072e+10  1.156520e+07
# 242  7.670000e+11  8.231972e+07
# 243  4.258778e+07  1.150800e+04
# 244  5.743707e+10  5.631835e+07
# 245  2.747695e+10  4.272314e+07
# 246  1.310000e+11  4.462252e+07
# 247  2.440000e+13  2.655636e+09
# 248  5.959689e+10  3.449299e+06
# 249  2.050000e+13  3.271674e+08
# 250  5.049992e+10  3.295540e+07
# 251  8.130940e+08  1.102100e+05
# 252  0.000000e+00  2.887020e+07
# 253  0.000000e+00  2.980200e+04
# 254  0.000000e+00  1.069770e+05
# 255  2.450000e+11  9.554040e+07
# 256  8.878179e+08  2.926800e+05
# 257  8.580000e+13  7.594270e+09
# 258  8.614947e+08  1.961300e+05
# 259  7.900269e+09  1.845300e+06
# 260  2.691440e+10  2.849869e+07
# 261  3.660000e+11  5.777962e+07
# 262  2.672007e+10  1.735182e+07
# 263  3.100052e+10  1.443902e+07
#
# [264 rows x 8 columns]

# %%
#for only use for to create json file

Export = world_income_df.to_json (r'C:\Users\hiral\Desktop\RutgersDataScienceBootCamp\Proj_3\Project_2_2019\World_IncomeLevel\source\worldMapData.json',orient='records')

# %%
#for to create geojson format file

def df_to_geojson(world_income_df, properties, lon='longitude', lat='latitude'):
    """
    Turn a dataframe containing point data into a geojson formatted python dictionary
    
    df : the dataframe to convert to geojson
    properties : a list of columns in the dataframe to turn into geojson feature properties
    lat : the name of the column in the dataframe that contains latitude data
    lon : the name of the column in the dataframe that contains longitude data
    """
    
    # create a new python dict to contain our geojson data, using geojson format
    geojson = {'type':'FeatureCollection', 'features':[]}

    # loop through each row in the dataframe and convert each row to geojson format
    for _, row in world_income_df.iterrows():
        # create a feature template to fill in
        feature = {'type':'Feature',
                   'properties':{},
                   'geometry':{'type':'Polygon',
                               'coordinates':[]}}

        # fill in the coordinates
        feature['geometry']['coordinates'] = [row[lon],row[lat]]

        # for each column, get the value and add it as a new feature property
        for prop in properties:
            feature['properties'][prop] = row[prop]
        
        # add this feature (aka, converted dataframe row) to the list of features inside our dict
        geojson['features'].append(feature)
    
    return geojson

# %%
useful_columns = ['Country Code','country_name','region','income_level','gdp','population']
geojson_dict = df_to_geojson(world_income_df, properties=useful_columns)
geojson_str = json.dumps(geojson_dict, indent=2)

# %%
# save the geojson result to a file
output_filename = 'wdataset.js'
with open(output_filename, 'w') as output_file:
    output_file.write('var wdataset = {};'.format(geojson_str))
    
# how many features did we save to the geojson file?
print('{} geotagged features saved to file'.format(len(geojson_dict['features'])))
# Out:
# 264 geotagged features saved to file

# %%
# set a variable that will call whatever column we want to visualise on the map
variable = ‘population’
# set the range for the choropleth
vmin, vmax = 120, 220
# create figure and axes for Matplotlib
fig, ax = plt.subplots(1, figsize=(10, 6))
# Out:
#   File "<ipython-input-25-4a667759f71b>", line 2
#     variable = ‘population’
#                           ^
# SyntaxError: invalid character in identifier
